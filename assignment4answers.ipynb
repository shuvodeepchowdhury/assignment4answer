# %% [raw]
# 1. What exactly is []?
#
# ANS:- [] is exactly the sign of representing a list , to create a empty list we can use a=[] and we can use it whenever we            want.
#
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value?                (Assume [2, 4, 6, 8, 10] are in spam.)
#
#
# ANS:- spam[2]='hello' ..  since we want the third position.
#
#       Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
#
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
#
# ANS:- 'd' is the answer.
#
# 4. What is the value of spam[-1]?
#
# ANS:- 'd' is the answer.
#
# 5. What is the value of spam[:2]?
#
# ANS:-['a','b'] isthe answer
#
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.  // question had a syntax error                 cat in the list should be in 'cat' in both the time
#
# 6. What is the value of bacon.index('cat')?
#
# ANS:- 1   (after correcting the syntax error)
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
#
# ANS:-[3.14, 'cat', 11, 'cat', True, 99] after appending and again running bacon.
#
# 8. How does bacon.remove('cat') change the look of the list in bacon?
#
# ANS:- [3.14, 11, 'cat', True, 99] after removing and again running bacon.
#
# 9. What are the list concatenation and list replication operators?
#
# ANS:-  *  is list replication operatotor.
#
#        a=[1,2]
#        a*2
#        [1,2,1,2]
#
#        +  is list cancatination operator.
#
#        a=[1,2]
#        b=[4,5]
#        a+b
#        [1, 2, 4, 5]
#
# 10. What is difference between the list methods append() and insert()?
#
# AND:-append() is used to Append object to the end of the list
#
#       bacon.append(99)
#       [3.14, 'cat', 11, 'cat', True, 99]
#
#      whereas,
#      insert() is used to Insert object before index
#
#        spam=[2, 4, 6, 8, 10]
#        spam[2]='hello'
#        [2, 4,,'hello', 6, 8, 10]
#
# 11. What are the two methods for removing items from a list?
#
# ANS:- one is bacon.remove('cat') as we have done in previous question
#        i.e using remove function
#
#        another using bacon.pop()
#        i.e using pop function
#
# 12. Describe how list values and string values are identical.
#
# ANS:- 1) list and strings can both be concatenated or replicated using + or *
#       2) both have indexes.
#       3) loops can be used in both string and list.
#       4) len() function can be used in both to determine their length.
#
# 13. What's the difference between tuples and lists?
#
# ANS:-The major difference in list that it is a mutable its value can be ADDED ,REMOVED,or can be CHANGED and list are enclosed      in third backet for e.g list=[1,2,3,4].
#           whereas, tuples are immutable that is its value cannot be added or removed. Tuples are created by using first                   brackets() for e.g- t=(1,2,3,4)
#
# 14. How do you type a tuple value that only contains the integer 42?
#
# ANS:- t=(42,)
#       t
#
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
#
# ANS:-LIST to TUPLE:-     l=[1,2,3]
#                          t=tuple(l)
#                          t
#                      output-- (1, 2, 3)
#      TUPLE to LIST:-     T=(1,2,3)
#                          l=list(l)
#                          l
#                      output-- [1, 2, 3]
#
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
#
# ANS:-Variables that contain list values are not necessarily lists themselves instead they contain reference to the list value.
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
#
# ANS:- A shallow copy of a List is reffered to copy.copy() .A shallow copy means constructing a new collection object and then         populating it with references to the child objects found in the original.
#       whereas The copy.deepcopy() function will do a deep copy of a list. only copy.deepcopy() will duplicate any lists inside       the list.
